# %%
import pandas as pd
df=pd.read_csv("Narayan.csv")
df
# Out:
#              Id    gene_1    gene_3    gene_5    gene_7    gene_8    gene_9  \
# 0    sample_313  0.554589 -1.758558 -0.822430 -0.453578  0.355311  2.174823
# 1    sample_427  1.159732  0.584532 -0.290216 -0.308697  0.858271  0.427662
# 2    sample_573 -0.241096 -0.523115 -0.464614 -0.413843 -0.024800 -0.020333
# 3    sample_214  1.277153  0.625642 -0.280942  0.290133 -0.296918  0.784187
# 4    sample_793  0.691170 -0.243284 -0.357550  0.348433 -0.653095  0.655224
# ..          ...       ...       ...       ...       ...       ...       ...
# 396   sample_99 -0.500795 -0.150836  0.062163  0.130155  0.263724 -0.140130
# 397  sample_719 -0.268482  1.610929 -0.177077 -0.473108       NaN  0.401110
# 398  sample_541       NaN -1.642649  0.924211 -1.042257 -0.329144 -3.079476
# 399  sample_720  0.184637 -0.310508 -0.596560 -0.359204 -0.175483 -0.033695
# 400  sample_695       NaN  1.067687 -0.187059 -0.951801  0.613369  0.338161
#
# ...

# %%
df.head()
# Out:
#            Id    gene_1    gene_3    gene_5    gene_7    gene_8    gene_9  \
# 0  sample_313  0.554589 -1.758558 -0.822430 -0.453578  0.355311  2.174823
# 1  sample_427  1.159732  0.584532 -0.290216 -0.308697  0.858271  0.427662
# 2  sample_573 -0.241096 -0.523115 -0.464614 -0.413843 -0.024800 -0.020333
# 3  sample_214  1.277153  0.625642 -0.280942  0.290133 -0.296918  0.784187
# 4  sample_793  0.691170 -0.243284 -0.357550  0.348433 -0.653095  0.655224
#
#     gene_10   gene_11   gene_13  ...  gene_20633  gene_20634  gene_20635  \
# 0 -0.746382  2.796776  1.356738  ...    0.814713   -0.917544   -1.174990
# 1  0.880553  1.083369 -0.617963  ...    0.544172   -1.447488   -0.624379
# 2 -0.236695 -0.448820       NaN  ...    1.959343    1.188033   -0.378787
# 3 -0.300130 -1.063136  0.190820  ...   -0.049144   -0.832593   -1.436841
# 4  0.236587       NaN  0.608754  ...    0.935813    0.694044    0.590808
#
#    gene_20636  gene_20637  gene_20638  gene_20639  gene_20640  gene_20641  \
# ...

# %%
df.tail()
# Out:
#              Id    gene_1    gene_3    gene_5    gene_7    gene_8    gene_9  \
# 396   sample_99 -0.500795 -0.150836  0.062163  0.130155  0.263724 -0.140130
# 397  sample_719 -0.268482  1.610929 -0.177077 -0.473108       NaN  0.401110
# 398  sample_541       NaN -1.642649  0.924211 -1.042257 -0.329144 -3.079476
# 399  sample_720  0.184637 -0.310508 -0.596560 -0.359204 -0.175483 -0.033695
# 400  sample_695       NaN  1.067687 -0.187059 -0.951801  0.613369  0.338161
#
#       gene_10   gene_11   gene_13  ...  gene_20633  gene_20634  gene_20635  \
# 396 -0.092166 -0.770439 -0.110419  ...    2.656869   -1.270529   -0.833994
# 397 -0.890010 -0.394700 -0.068084  ...    0.499538    0.125061   -0.520652
# 398 -1.009529  0.843019 -0.723763  ...   -0.763529    0.590048    0.194047
# 399 -0.616092  0.569388 -0.312337  ...   -0.343914   -1.088941   -1.581313
# 400 -0.679334 -0.286525 -0.566736  ...    0.473432   -1.912336   -0.873637
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Columns: 14573 entries, Id to gene_20642
# dtypes: float64(14572), str(1)
# memory usage: 44.6 MB

# %%
df.shape
# Out:
# (401, 14573)

# %%
df.columns
# Out:
# Index(['Id', 'gene_1', 'gene_3', 'gene_5', 'gene_7', 'gene_8', 'gene_9',
#        'gene_10', 'gene_11', 'gene_13',
#        ...
#        'gene_20633', 'gene_20634', 'gene_20635', 'gene_20636', 'gene_20637',
#        'gene_20638', 'gene_20639', 'gene_20640', 'gene_20641', 'gene_20642'],
#       dtype='str', length=14573)

# %%
df["gene_20638"].unique()
# Out:
# array([ 8.39969250e-02,  6.77765262e-01, -7.10643151e-02,             nan,
#        -1.72309669e+00, -8.87851644e-01,  6.14646913e-01,  1.00817704e+00,
#         3.51430151e-01, -5.15890603e-01, -6.50055149e-01,  5.76507551e-01,
#        -5.93238419e-01,  1.85054708e-01, -3.60328423e-02,  1.41376598e+00,
#        -5.93887970e-02,  9.91402981e-01, -5.15554468e-01, -1.03385239e+00,
#         3.81411899e+00, -8.65386551e-01, -5.44564943e-01,  1.96318360e+00,
#        -7.98578752e-01,  6.30029469e-01, -1.41502123e-01,  1.27575022e+00,
#         4.37110477e-01,  8.34460154e-01,  2.18862805e-01, -1.68457710e-01,
#        -1.23078017e+00,  9.38363686e-01,  2.89848990e+00, -1.14097584e-01,
#        -1.65283308e-01, -9.91858009e-01,  1.17267758e+00, -3.48193337e-01,
#         1.59005453e+00, -1.65415316e+00, -1.01934826e-01,  4.55247564e-02,
#        -1.53840261e-01, -9.50997278e-01, -5.95520218e-01,  1.02499601e-01,
# ...

# %%
df["gene_10007"].unique()
# Out:
# array([            nan, -4.69322206e-01,  1.28299413e+00, -2.42250724e-03,
#         7.09864384e-02, -3.08669998e-01,  9.29324164e-01, -6.46813418e-01,
#         1.03691435e+00,  9.76451834e-01, -4.98393175e-01, -7.01566944e-01,
#         4.33554064e-01, -5.21614675e-01, -8.70703761e-01, -5.10262737e-01,
#        -6.83576376e-01, -9.32389673e-01, -5.05298687e-01, -3.90785703e-01,
#         1.14099883e+00,  6.53584317e-01,  1.46462812e+00,  1.69687236e-01,
#        -8.41282912e-01,  2.30297733e+00,  2.75128901e-01, -9.66722999e-01,
#        -1.46795522e+00, -2.04411993e-01,  7.74415400e-02, -2.50877058e-01,
#        -9.86369362e-01,  2.00171707e-01, -7.06410950e-01,  1.56917148e+00,
#         2.12073534e+00,  2.26029151e-01, -3.16004857e-02, -8.30660574e-01,
#        -7.43338565e-01,  4.88450069e-01,  3.99308761e-02, -2.89263612e-01,
#         4.29945785e-01, -9.58089749e-01, -5.06703177e-01,  2.27862968e-01,
# ...

# %%
df["gene_20638"].value_counts()
# Out:
# gene_20638
#  0.083997    1
#  0.677765    1
# -0.071064    1
# -1.723097    1
# -0.887852    1
#             ..
#  0.892427    1
# -0.218646    1
# -0.163563    1
#  1.420717    1
#  0.727436    1
# Name: count, Length: 356, dtype: int64

# %%
df.describe()
# Out:
#            gene_1      gene_3      gene_5      gene_7      gene_8      gene_9  \
# count  363.000000  376.000000  369.000000  358.000000  365.000000  362.000000
# mean    -0.022679   -0.036010   -0.055106   -0.029883   -0.037499    0.008865
# std      1.025239    1.061043    1.017263    1.084526    1.084968    1.202855
# min     -3.153783   -2.823982   -5.226497   -4.219470   -5.294371   -4.192676
# 25%     -0.729222   -0.637828   -0.557869   -0.677782   -0.412703   -0.414649
# 50%     -0.161152   -0.134671   -0.006819   -0.173784   -0.000658   -0.020410
# 75%      0.555771    0.403489    0.379680    0.438119    0.398271    0.427375
# max      4.644523    6.863024    3.496562    6.858772    4.087764    9.777850
#
#           gene_10     gene_11     gene_13     gene_14  ...  gene_20633  \
# count  366.000000  370.000000  368.000000  370.000000  ...  373.000000
# mean     0.032273   -0.009048    0.012085    0.071947  ...   -0.041427
# ...
